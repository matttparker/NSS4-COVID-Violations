# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import math
from datetime import datetime
from tqdm.notebook import tqdm
import glob
import json
import seaborn as sns
# %matplotlib inline

# %%
clusters_violations_geo = pd.read_csv('../data/clusters_violations_geo_df.csv')

# %%
clusters_violations_geo.head()
# Out:
#    Unnamed: 0                Cluster Name      Facility Type  \
# 0           0    Event at Clementine Hall   Social Gathering
# 1           1  Rescue Mission-Fairgrounds  Congregate Living
# 2           2      The Opal at Music City               LTCF
# 3           3      The Opal at Music City               LTCF
# 4           4      The Opal at Music City               LTCF
#
#     Cluster Start Date  # Cases  Latitude  Longitude  Request #  Status  \
# 0  2020-03-14 00:00:00       23    36.152    -86.847     407619  Closed
# 1  2020-04-30 00:00:00      156    36.145    -86.765     360354  Closed
# 2  2020-06-03 00:00:00       27    36.162    -86.663     388854  Closed
# 3  2020-06-03 00:00:00       27    36.162    -86.663     417578  Closed
# 4  2020-06-03 00:00:00       27    36.162    -86.663     431369  Closed
#
#     Date / Time Opened  ...         Street  Unit Type  Unit Number     City.1  \
# 0  2020-07-04 16:47:23  ...  Charlotte Ave        NaN          NaN  Nashville
# ...

# %%
clusters_violations_geo['Cluster Name'].value_counts()
# Out:
# Kid Rock's Big Ass Honky Tonk    52
# Dogwood                           5
# Loser's                           4
# The Opal at Music City            3
# Rescue Mission-Fairgrounds        1
# Lipscomb Elam Hall job site       1
# Event at Clementine Hall          1
# Miss Kelli's                      1
# Dawghouse Saloon                  1
# Name: Cluster Name, dtype: int64

# %%
fig = px.timeline(clusters_violations_geo, x_start=)

# %%
df = pd.DataFrame([
    dict(Task="Job A", Start='2009-01-01', Finish='2009-02-28', Completion_pct=50),
    dict(Task="Job B", Start='2009-03-05', Finish='2009-04-15', Completion_pct=25),
    dict(Task="Job C", Start='2009-02-20', Finish='2009-05-30', Completion_pct=75)
])

fig = px.timeline(df, x_start="Start", x_end="Finish", y="Task", color="Completion_pct")
fig.update_yaxes(autorange="reversed")
fig.show()

# %%
clusters = pd.read_csv('../data/clusters.csv')

# %%
clusters.sort_values('# Cases', ascending=False).head(20)
# Out:
#                                   Cluster Name          Facility Type  \
# 5                                  Tyson Foods   Commercial-Warehouse
# 50     Debra Johnson Rehab/TN Prison for Women  Correctional Facility
# 12                  Rescue Mission-Fairgrounds      Congregate Living
# 10        Bethany Center for Rehab and Healing                   LTCF
# 44                                   CoreCivic  Correctional Facility
# 21      Creekside Center for Rehab and Healing                   LTCF
# 4        Trevecca Center for Rehab and Healing                   LTCF
# 23                              Hermitage Hall      Congregate Living
# 14            Montgomery Bell Academy job site           Construction
# 16             Good Samaritan Health & Healing                   LTCF
# 26                                    CDM Jail  Correctional Facility
# 59   Nashville Rescue Mission - Women's Campus      Congregate Living
# ...

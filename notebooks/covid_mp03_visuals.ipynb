# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from datetime import datetime
from tqdm.notebook import tqdm
import seaborn as sns
import altair as alt
# %matplotlib inline

# %%
fuzzy_clusters_df = pd.read_csv('../data/fuzzy_merge_df.csv')

# %%
fuzzy_clusters_df.head()
# Out:
#    Unnamed: 0                           Cluster Name        Street_clusters  \
# 0           0  Trevecca Center for Rehab and Healing  329 Murfreesboro Pike
# 1           1       Montgomery Bell Academy job site      4001 Harding Pike
# 2           2       Montgomery Bell Academy job site      4001 Harding Pike
# 3           3       Montgomery Bell Academy job site      4001 Harding Pike
# 4           4       Montgomery Bell Academy job site      4001 Harding Pike
#
#   City_clusters State_clusters Facility Type Cluster Start Date  # Cases  \
# 0     Nashville             TN          LTCF             4/4/20      102
# 1     Nashville             TN  Construction             5/8/20       75
# 2     Nashville             TN  Construction             5/8/20       75
# 3     Nashville             TN  Construction             5/8/20       75
# 4     Nashville             TN  Construction             5/8/20       75
#
#    Latitude_clusters  Longitude_clusters  ...  Latitude_violations  \
# 0          36.144764          -86.755659  ...            36.144764
# 1          36.093008          -86.845540  ...            36.093008
# 2          36.093008          -86.845540  ...            36.093008
# 3          36.093008          -86.845540  ...            36.093008
# 4          36.093008          -86.845540  ...            36.093008
#
#   Longitude_violations Accuracy Score_violations  Accuracy Type_violations  \
# 0           -86.755659                       1.0                   rooftop
# 1           -86.845540                       0.7       range_interpolation
# 2           -86.845540                       0.7       range_interpolation
# 3           -86.845540                       0.7       range_interpolation
# 4           -86.845540                       0.7       range_interpolation
#
#   Number  Street_violations     City.1 State_violations County_violations  \
# 0    329  Murfreesboro Pike  Nashville               TN   Davidson County
# 1   4001         Harding Pl  Nashville               TN   Davidson County
# 2   4001         Harding Pl  Nashville               TN   Davidson County
# 3   4001         Harding Pl  Nashville               TN   Davidson County
# 4   4001         Harding Pl  Nashville               TN   Davidson County
#
#    Zip_violations
# 0           37210
# 1           37215
# 2           37215
# 3           37215
# 4           37215
#
# [5 rows x 41 columns]

# %%
sters = pd.read_csv('../data/clusters_corrected-Sheet1-2_geocodio_d08379641999d429faecf949b19c4c6f08c2732c.csv')

# %%
fuzzy_clusters_df[fuzzy_clusters_df['Cluster Name'] == "Winner's"]
# Out:
#      Unnamed: 0 Cluster Name   Street_clusters City_clusters State_clusters  \
# 109         109     Winner's  1913 Division St     Nashville             TN
# 110         110     Winner's  1913 Division St     Nashville             TN
# 111         111     Winner's  1913 Division St     Nashville             TN
# 112         112     Winner's  1913 Division St     Nashville             TN
# 113         113     Winner's  1913 Division St     Nashville             TN
# 114         114     Winner's  1913 Division St     Nashville             TN
# 115         115     Winner's  1913 Division St     Nashville             TN
# 116         116     Winner's  1913 Division St     Nashville             TN
# 117         117     Winner's  1913 Division St     Nashville             TN
# 118         118     Winner's  1913 Division St     Nashville             TN
# 119         119     Winner's  1913 Division St     Nashville             TN
# 120         120     Winner's  1913 Division St     Nashville             TN
# 121         121     Winner's  1913 Division St     Nashville             TN
# 122         122     Winner's  1913 Division St     Nashville             TN
# 123         123     Winner's  1913 Division St     Nashville             TN
# 124         124     Winner's  1913 Division St     Nashville             TN
# 125         125     Winner's  1913 Division St     Nashville             TN
# 126         126     Winner's  1913 Division St     Nashville             TN
# 127         127     Winner's  1913 Division St     Nashville             TN
# 128         128     Winner's  1913 Division St     Nashville             TN
# 129         129     Winner's  1913 Division St     Nashville             TN
# 130         130     Winner's  1913 Division St     Nashville             TN
# 131         131     Winner's  1913 Division St     Nashville             TN
# 132         132     Winner's  1913 Division St     Nashville             TN
# 133         133     Winner's  1913 Division St     Nashville             TN
# 134         134     Winner's  1913 Division St     Nashville             TN
# 135         135     Winner's  1913 Division St     Nashville             TN
#
#     Facility Type Cluster Start Date  # Cases  Latitude_clusters  \
# 109           Bar            6/26/20       10          36.149569
# 110           Bar            6/26/20       10          36.149569
# 111           Bar            6/26/20       10          36.149569
# 112           Bar            6/26/20       10          36.149569
# 113           Bar            6/26/20       10          36.149569
# 114           Bar            6/26/20       10          36.149569
# 115           Bar            6/26/20       10          36.149569
# 116           Bar            6/26/20       10          36.149569
# 117           Bar            6/26/20       10          36.149569
# 118           Bar            6/26/20       10          36.149569
# 119           Bar            6/26/20       10          36.149569
# 120           Bar            6/26/20       10          36.149569
# 121           Bar            6/26/20       10          36.149569
# 122           Bar            6/26/20       10          36.149569
# 123           Bar            6/26/20       10          36.149569
# 124           Bar            6/26/20       10          36.149569
# 125           Bar            6/26/20       10          36.149569
# 126           Bar            6/26/20       10          36.149569
# 127           Bar            6/26/20       10          36.149569
# 128           Bar            6/26/20       10          36.149569
# 129           Bar            6/26/20       10          36.149569
# 130           Bar            6/26/20       10          36.149569
# 131           Bar            6/26/20       10          36.149569
# 132           Bar            6/26/20       10          36.149569
# 133           Bar            6/26/20       10          36.149569
# 134           Bar            6/26/20       10          36.149569
# 135           Bar            6/26/20       10          36.149569
#
#      Longitude_clusters  ...  Latitude_violations Longitude_violations  \
# 109          -86.796895  ...            36.149569           -86.796895
# 110          -86.796895  ...            36.149569           -86.796895
# 111          -86.796895  ...            36.149569           -86.796895
# 112          -86.796895  ...            36.149569           -86.796895
# 113          -86.796895  ...            36.149569           -86.796895
# 114          -86.796895  ...            36.149569           -86.796895
# 115          -86.796895  ...            36.149569           -86.796895
# 116          -86.796895  ...            36.149569           -86.796895
# 117          -86.796895  ...            36.149569           -86.796895
# 118          -86.796895  ...            36.149569           -86.796895
# 119          -86.796895  ...            36.149569           -86.796895
# 120          -86.796895  ...            36.149569           -86.796895
# 121          -86.796895  ...            36.149569           -86.796895
# 122          -86.796895  ...            36.149569           -86.796895
# 123          -86.796895  ...            36.149569           -86.796895
# 124          -86.796895  ...            36.149569           -86.796895
# 125          -86.796895  ...            36.149569           -86.796895
# 126          -86.796895  ...            36.149569           -86.796895
# 127          -86.796895  ...            36.149569           -86.796895
# 128          -86.796895  ...            36.149569           -86.796895
# 129          -86.796895  ...            36.149569           -86.796895
# 130          -86.796895  ...            36.149569           -86.796895
# 131          -86.796895  ...            36.149569           -86.796895
# 132          -86.796895  ...            36.149569           -86.796895
# 133          -86.796895  ...            36.149569           -86.796895
# 134          -86.796895  ...            36.149569           -86.796895
# 135          -86.796895  ...            36.149569           -86.796895
#
#     Accuracy Score_violations  Accuracy Type_violations Number  \
# 109                       1.0                   rooftop   1913
# 110                       1.0                   rooftop   1913
# 111                       1.0                   rooftop   1913
# 112                       1.0                   rooftop   1913
# 113                       1.0                   rooftop   1913
# 114                       1.0                   rooftop   1913
# 115                       1.0                   rooftop   1913
# 116                       1.0                   rooftop   1913
# 117                       1.0                   rooftop   1913
# 118                       1.0                   rooftop   1913
# 119                       1.0                   rooftop   1913
# 120                       1.0                   rooftop   1913
# 121                       1.0                   rooftop   1913
# 122                       1.0                   rooftop   1913
# 123                       1.0                   rooftop   1913
# 124                       1.0                   rooftop   1913
# 125                       1.0                   rooftop   1913
# 126                       1.0                   rooftop   1913
# 127                       1.0                   rooftop   1913
# 128                       1.0                   rooftop   1913
# 129                       1.0                   rooftop   1913
# 130                       1.0                   rooftop   1913
# 131                       1.0                   rooftop   1913
# 132                       1.0                   rooftop   1913
# 133                       1.0                   rooftop   1913
# 134                       1.0                   rooftop   1913
# 135                       1.0                   rooftop   1913
#
#      Street_violations     City.1 State_violations County_violations  \
# 109        Division St  Nashville               TN   Davidson County
# 110        Division St  Nashville               TN   Davidson County
# 111        Division St  Nashville               TN   Davidson County
# 112        Division St  Nashville               TN   Davidson County
# 113        Division St  Nashville               TN   Davidson County
# 114        Division St  Nashville               TN   Davidson County
# 115        Division St  Nashville               TN   Davidson County
# 116        Division St  Nashville               TN   Davidson County
# 117        Division St  Nashville               TN   Davidson County
# 118        Division St  Nashville               TN   Davidson County
# 119        Division St  Nashville               TN   Davidson County
# 120        Division St  Nashville               TN   Davidson County
# 121        Division St  Nashville               TN   Davidson County
# 122        Division St  Nashville               TN   Davidson County
# 123        Division St  Nashville               TN   Davidson County
# 124        Division St  Nashville               TN   Davidson County
# 125        Division St  Nashville               TN   Davidson County
# 126        Division St  Nashville               TN   Davidson County
# 127        Division St  Nashville               TN   Davidson County
# 128        Division St  Nashville               TN   Davidson County
# 129        Division St  Nashville               TN   Davidson County
# 130        Division St  Nashville               TN   Davidson County
# 131        Division St  Nashville               TN   Davidson County
# 132        Division St  Nashville               TN   Davidson County
# 133        Division St  Nashville               TN   Davidson County
# 134        Division St  Nashville               TN   Davidson County
# 135        Division St  Nashville               TN   Davidson County
#
#      Zip_violations
# 109           37203
# 110           37203
# 111           37203
# 112           37203
# 113           37203
# 114           37203
# 115           37203
# 116           37203
# 117           37203
# 118           37203
# 119           37203
# 120           37203
# 121           37203
# 122           37203
# 123           37203
# 124           37203
# 125           37203
# 126           37203
# 127           37203
# 128           37203
# 129           37203
# 130           37203
# 131           37203
# 132           37203
# 133           37203
# 134           37203
# 135           37203
#
# [27 rows x 41 columns]

# %%
cluster_info = fuzzy_clusters_df.drop_duplicates(subset='Cluster Name', keep='first')
cluster_info = cluster_info.groupby(['Facility Type'])['# Cases'].agg(['nunique', 'sum', 'mean'])
cluster_info
# Out:
#                        nunique  sum        mean
# Facility Type
# Bar                          5  109   18.166667
# Church                       1   10   10.000000
# Congregate Living            3  213   71.000000
# Construction                 2   98   49.000000
# Correctional Facility        3  338  112.666667
# Gym                          1   14   14.000000
# LTCF                         8  377   47.125000
# Office                       1   18   18.000000
# Other                        2   35   17.500000
# Restaurant                   1   19   19.000000

# %%
fuzzy_clusters_df.groupby(['Cluster Name'])['# Cases'].mean()
# Out:
# Cluster Name
# Ahava / Grace Healthcare of White's Creek         46
# Belmont Village of Green Hills                    16
# Dawghouse Saloon                                  14
# Debra Johnson Rehab/TN Prison for Women          216
# Dogwood                                           19
# Good Samaritan Health & Healing                   75
# Grand Hyatt Hotel (Power Design Inc) job site     23
# Green Hills Center for Rehab and Healing          45
# Hermitage Hall                                    93
# Iron Tribe Belmont                                14
# Kid Rock's Big Ass Honky Tonk                     15
# Lakeshore Meadows                                 33
# Life Care Center Old Hickory Village              11
# Link Systems Electric                             12
# Lois DeBerry Special Needs Facility               62
# Loser's                                           29
# Metro Water Services                              18
# Miss Kelli's                                      14
# Montgomery Bell Academy job site                  75
# Nashville Center for Rehab and Healing (2)        49
# Nashville Rescue Mission - Women's Campus         70
# One Stone Church Service                          10
# Riverbend Max Security Prison-2                   60
# Standing Tall Music City                          50
# Tennessee Titans                                  23
# Tootsie's                                         27
# Trevecca Center for Rehab and Healing            102
# Winner's                                          10
# Name: # Cases, dtype: int64

# %%
plt.figure(figsize=(14,9))
sns.countplot(y='Cluster Name', 
              data=fuzzy_clusters_df, 
              order = fuzzy_clusters_df['Cluster Name'].value_counts().index,
              color='midnightblue')
plt.xlabel('# Reported Violations', size=15)
plt.ylabel('Cluster Name', size=15)
plt.title('Cluster Locations by Number of Reported Violations', size=18);

plt.tight_layout()
plt.savefig('cluster_barplot_1.png', dpi=100)

# %%
plt.figure(figsize=(14,9))
count_plot = sns.countplot(y='Cluster Name', 
              data=fuzzy_clusters_df, 
              order = fuzzy_clusters_df['Cluster Name'].value_counts().index,
              color="midnightblue")
plt.xlabel('# Reported Violations', size=15)
plt.ylabel('Cluster Name', size=15)
plt.title('Cluster Locations by Number of Reported Violations', size=18);

for bar in count_plot.patches:
    if bar.get_width() > 6:
        bar.set_color('orange')

count_plot;

plt.tight_layout()
#plt.savefig('cluster_barplot_2.png', dpi=100)

# %%
top_five_violations = fuzzy_clusters_df['Cluster Name'].value_counts().sort_values(
    ascending=False).head().index.to_list()
top_five_violations
# Out:
# ["Kid Rock's Big Ass Honky Tonk",
#  "Tootsie's",
#  "Winner's",
#  'Dawghouse Saloon',
#  'Montgomery Bell Academy job site']

# %%
plt.figure(figsize=(14,9))
data=fuzzy_clusters_df.drop_duplicates(subset='Cluster Name', keep='first').sort_values('# Cases', ascending=False)
clrs = ['orange' if name in top_five_violations else 'midnightblue' for name in data['Cluster Name']]
bar_plot = sns.barplot(x='# Cases', y = 'Cluster Name',
              data=data, 
              palette=clrs)
plt.xlabel('# Cases in Cluster', size=15)
plt.ylabel('Cluster Name', size=15)
plt.title('# Cases by Cluster Location', size=18);

bar_plot;

plt.tight_layout()
#plt.savefig('cluster_barplot_3.png', dpi=100)

# %%
violations_top_10 = fuzzy_clusters_df['Cluster Name'].value_counts().head(10).index.to_list()

# %%
fuzzy_strip = fuzzy_clusters_df[fuzzy_clusters_df['Cluster Name'].isin(violations_top_10)]

# %%
fuzzy_strip['Date / Time Opened'] = pd.to_datetime(fuzzy_strip['Date / Time Opened'])
fuzzy_strip['Cluster Start Date'] = pd.to_datetime(fuzzy_strip['Cluster Start Date'])
# Out:
# <ipython-input-14-929db17d26b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fuzzy_strip['Date / Time Opened'] = pd.to_datetime(fuzzy_strip['Date / Time Opened'])
# <ipython-input-14-929db17d26b4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fuzzy_strip['Cluster Start Date'] = pd.to_datetime(fuzzy_strip['Cluster Start Date'])

# %%
fuzzy_strip['Facility Type'].value_counts()
# Out:
# Bar                  116
# LTCF                  11
# Construction           8
# Congregate Living      6
# Other                  4
# Name: Facility Type, dtype: int64

# %%
fuzzy_strip['Facility Type'] = fuzzy_strip['Facility Type'].map({
    'Bar': 'Bar',
    'Construction': 'Other Business',
    'Other': 'Other Business',
    'LTCF': 'LTCF/Living',
    'Congregate Living': 'LTCF/Living'})
# Out:
# <ipython-input-16-370dbb49c446>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fuzzy_strip['Facility Type'] = fuzzy_strip['Facility Type'].map({

# %%
fuzzy_strip.T
# Out:
#                                                         1    \
# Unnamed: 0                                                1
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                Other Business
# Cluster Start Date                      2020-05-08 00:00:00
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            339597
# Status                                               Closed
# Date / Time Opened                      2020-04-05 17:13:59
# Date / Time Closed                      2020-04-10 17:19:55
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location            (36.12837600000001, -86.8345785)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         2    \
# Unnamed: 0                                                2
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                Other Business
# Cluster Start Date                      2020-05-08 00:00:00
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            338380
# Status                                               Closed
# Date / Time Opened                      2020-04-03 14:32:43
# Date / Time Closed                      2020-04-10 17:23:47
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location                       (36.12842, -86.83669)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         3    \
# Unnamed: 0                                                3
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                Other Business
# Cluster Start Date                      2020-05-08 00:00:00
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            338362
# Status                                               Closed
# Date / Time Opened                      2020-04-03 14:23:57
# Date / Time Closed                      2020-04-10 17:19:39
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location            (36.12837600000001, -86.8345785)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         4    \
# Unnamed: 0                                                4
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                Other Business
# Cluster Start Date                      2020-05-08 00:00:00
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            360377
# Status                                               Closed
# Date / Time Opened                      2020-05-06 14:42:30
# Date / Time Closed                      2020-05-07 15:09:19
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location                   (36.1284249, -86.8366934)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         5    \
# Unnamed: 0                                                5
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                Other Business
# Cluster Start Date                      2020-05-08 00:00:00
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            365255
# Status                                               Closed
# Date / Time Opened                      2020-05-12 17:04:53
# Date / Time Closed                      2020-05-13 16:37:42
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location                   (36.1277086, -86.8366003)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                         6    \
# Unnamed: 0                                                6
# Cluster Name               Montgomery Bell Academy job site
# Street_clusters                           4001 Harding Pike
# City_clusters                                     Nashville
# State_clusters                                           TN
# Facility Type                                Other Business
# Cluster Start Date                      2020-05-08 00:00:00
# # Cases                                                  75
# Latitude_clusters                                    36.093
# Longitude_clusters                                 -86.8455
# Accuracy Score_clusters                                 0.7
# Accuracy Type_clusters                  range_interpolation
# County_clusters                             Davidson County
# Zip_clusters                                          37215
# matches                                   4001 Harding Pike
# Request #                                            401263
# Status                                               Closed
# Date / Time Opened                      2020-06-26 13:52:13
# Date / Time Closed                      2020-06-29 18:36:50
# Contact Type                                            NaN
# State Issue                                           False
# Closed When Created                                   False
# Address                                   4001 Harding Pike
# City_violations                                   NASHVILLE
# Council District                                         24
# ZIP                                                   37205
# Mapped Location                       (36.12853, -86.83647)
# Address_geo                               4001 Harding Pike
# City_geo                                          NASHVILLE
# ZIP_geo                                               37205
# state                                                    TN
# Latitude_violations                                  36.093
# Longitude_violations                               -86.8455
# Accuracy Score_violations                               0.7
# Accuracy Type_violations                range_interpolation
# Number                                                 4001
# Street_violations                                Harding Pl
# City.1                                            Nashville
# State_violations                                         TN
# County_violations                           Davidson County
# Zip_violations                                        37215
#
#                                                                 7    \
# Unnamed: 0                                                        7
# Cluster Name                       Montgomery Bell Academy job site
# Street_clusters                                   4001 Harding Pike
# City_clusters                                             Nashville
# State_clusters                                                   TN
# Facility Type                                        Other Business
# Cluster Start Date                              2020-05-08 00:00:00
# # Cases                                                          75
# Latitude_clusters                                            36.093
# Longitude_clusters                                         -86.8455
# Accuracy Score_clusters                                         0.7
# Accuracy Type_clusters                          range_interpolation
# County_clusters                                     Davidson County
# Zip_clusters                                                  37215
# matches                                           4001 Harding Pike
# Request #                                                    435775
# Status                                                       Closed
# Date / Time Opened                              2020-08-03 05:23:34
# Date / Time Closed                              2020-08-03 17:52:24
# Contact Type                                                    NaN
# State Issue                                                   False
# Closed When Created                                           False
# Address                                           4001 Harding Pike
# City_violations                                           NASHVILLE
# Council District                                                 24
# ZIP                                                           37205
# Mapped Location            (36.127867291643206, -86.83734249458159)
# Address_geo                                       4001 Harding Pike
# City_geo                                                  NASHVILLE
# ZIP_geo                                                       37205
# state                                                            TN
# Latitude_violations                                          36.093
# Longitude_violations                                       -86.8455
# Accuracy Score_violations                                       0.7
# Accuracy Type_violations                        range_interpolation
# Number                                                         4001
# Street_violations                                        Harding Pl
# City.1                                                    Nashville
# State_violations                                                 TN
# County_violations                                   Davidson County
# Zip_violations                                                37215
#
#                                                          8    \
# Unnamed: 0                                                 8
# Cluster Name                Montgomery Bell Academy job site
# Street_clusters                            4001 Harding Pike
# City_clusters                                      Nashville
# State_clusters                                            TN
# Facility Type                                 Other Business
# Cluster Start Date                       2020-05-08 00:00:00
# # Cases                                                   75
# Latitude_clusters                                     36.093
# Longitude_clusters                                  -86.8455
# Accuracy Score_clusters                                  0.7
# Accuracy Type_clusters                   range_interpolation
# County_clusters                              Davidson County
# Zip_clusters                                           37215
# matches                                    4001 Harding Pike
# Request #                                             475228
# Status                                                Closed
# Date / Time Opened                       2020-10-04 14:57:01
# Date / Time Closed                       2020-10-05 13:53:06
# Contact Type                                             NaN
# State Issue                                            False
# Closed When Created                                    False
# Address                                    4001 Harding Pike
# City_violations                                    NASHVILLE
# Council District                                          24
# ZIP                                                    37205
# Mapped Location            (36.12879426159236, -86.83709815)
# Address_geo                                4001 Harding Pike
# City_geo                                           NASHVILLE
# ZIP_geo                                                37205
# state                                                     TN
# Latitude_violations                                   36.093
# Longitude_violations                                -86.8455
# Accuracy Score_violations                                0.7
# Accuracy Type_violations                 range_interpolation
# Number                                                  4001
# Street_violations                                 Harding Pl
# City.1                                             Nashville
# State_violations                                          TN
# County_violations                            Davidson County
# Zip_violations                                         37215
#
#                                                        11   \
# Unnamed: 0                                              11
# Cluster Name               Good Samaritan Health & Healing
# Street_clusters                 500 Hickory Hollow Terrace
# City_clusters                                      Antioch
# State_clusters                                          TN
# Facility Type                                  LTCF/Living
# Cluster Start Date                     2020-06-03 00:00:00
# # Cases                                                 75
# Latitude_clusters                                  36.0524
# Longitude_clusters                                -86.6483
# Accuracy Score_clusters                                0.8
# Accuracy Type_clusters                 range_interpolation
# County_clusters                            Davidson County
# Zip_clusters                                         37013
# matches                         500 Hickory Hollow Terrace
# Request #                                           354105
# Status                                              Closed
# Date / Time Opened                     2020-04-28 16:07:45
# Date / Time Closed                     2020-05-07 15:17:06
# Contact Type                                           NaN
# State Issue                                          False
# Closed When Created                                  False
# Address                         500 Hickory Hollow Terrace
# City_violations                                    ANTIOCH
# Council District                                        32
# ZIP                                                  37013
# Mapped Location                      (36.05338, -86.64929)
# Address_geo                     500 Hickory Hollow Terrace
# City_geo                                           ANTIOCH
# ZIP_geo                                              37013
# state                                                   TN
# Latitude_violations                                36.0524
# Longitude_violations                              -86.6483
# Accuracy Score_violations                              0.8
# Accuracy Type_violations               range_interpolation
# Number                                                 500
# Street_violations                       Hickory Hollow Ter
# City.1                                             Antioch
# State_violations                                        TN
# County_violations                          Davidson County
# Zip_violations                                       37013
#
#                                                        12   ...  \
# Unnamed: 0                                              12  ...
# Cluster Name               Good Samaritan Health & Healing  ...
# Street_clusters                 500 Hickory Hollow Terrace  ...
# City_clusters                                      Antioch  ...
# State_clusters                                          TN  ...
# Facility Type                                  LTCF/Living  ...
# Cluster Start Date                     2020-06-03 00:00:00  ...
# # Cases                                                 75  ...
# Latitude_clusters                                  36.0524  ...
# Longitude_clusters                                -86.6483  ...
# Accuracy Score_clusters                                0.8  ...
# Accuracy Type_clusters                 range_interpolation  ...
# County_clusters                            Davidson County  ...
# Zip_clusters                                         37013  ...
# matches                         500 Hickory Hollow Terrace  ...
# Request #                                           350510  ...
# Status                                              Closed  ...
# Date / Time Opened                     2020-04-22 15:13:37  ...
# Date / Time Closed                     2020-04-24 15:25:54  ...
# Contact Type                                           NaN  ...
# State Issue                                          False  ...
# Closed When Created                                  False  ...
# Address                         500 Hickory Hollow Terrace  ...
# City_violations                                    ANTIOCH  ...
# Council District                                        32  ...
# ZIP                                                  37013  ...
# Mapped Location                      (36.05338, -86.64929)  ...
# Address_geo                     500 Hickory Hollow Terrace  ...
# City_geo                                           ANTIOCH  ...
# ZIP_geo                                              37013  ...
# state                                                   TN  ...
# Latitude_violations                                36.0524  ...
# Longitude_violations                              -86.6483  ...
# Accuracy Score_violations                              0.8  ...
# Accuracy Type_violations               range_interpolation  ...
# Number                                                 500  ...
# Street_violations                       Hickory Hollow Ter  ...
# City.1                                             Antioch  ...
# State_violations                                        TN  ...
# County_violations                          Davidson County  ...
# Zip_violations                                       37013  ...
#
#                                                 155                      156  \
# Unnamed: 0                                      155                      156
# Cluster Name                           Miss Kelli's             Miss Kelli's
# Street_clusters                  207 Printers Alley       207 Printers Alley
# City_clusters                             Nashville                Nashville
# State_clusters                                   TN                       TN
# Facility Type                                   Bar                      Bar
# Cluster Start Date              2020-10-01 00:00:00      2020-10-01 00:00:00
# # Cases                                          14                       14
# Latitude_clusters                           36.1639                  36.1639
# Longitude_clusters                         -86.7785                 -86.7785
# Accuracy Score_clusters                           1                        1
# Accuracy Type_clusters          range_interpolation      range_interpolation
# County_clusters                     Davidson County          Davidson County
# Zip_clusters                                  37201                    37201
# matches                          207 Printers Alley       207 Printers Alley
# Request #                                    425971                   391515
# Status                                       Closed                   Closed
# Date / Time Opened              2020-07-24 19:47:49      2020-06-13 04:43:17
# Date / Time Closed              2020-07-27 19:44:25      2020-06-15 15:32:01
# Contact Type                                    NaN                      NaN
# State Issue                                   False                    False
# Closed When Created                           False                    False
# Address                          207 Printers Alley       207 Printers Alley
# City_violations                           NASHVILLE                NASHVILLE
# Council District                                 19                       19
# ZIP                                           37201                    37201
# Mapped Location            (36.1643694, -86.778515)  (36.164369, -86.778515)
# Address_geo                      207 Printers Alley       207 Printers Alley
# City_geo                                  NASHVILLE                NASHVILLE
# ZIP_geo                                       37201                    37201
# state                                            TN                       TN
# Latitude_violations                         36.1639                  36.1639
# Longitude_violations                       -86.7785                 -86.7785
# Accuracy Score_violations                         1                        1
# Accuracy Type_violations        range_interpolation      range_interpolation
# Number                                          207                      207
# Street_violations                      Printers Aly             Printers Aly
# City.1                                    Nashville                Nashville
# State_violations                                 TN                       TN
# County_violations                   Davidson County          Davidson County
# Zip_violations                                37201                    37201
#
#                                              157                      158  \
# Unnamed: 0                                   157                      158
# Cluster Name                        Miss Kelli's             Miss Kelli's
# Street_clusters               207 Printers Alley       207 Printers Alley
# City_clusters                          Nashville                Nashville
# State_clusters                                TN                       TN
# Facility Type                                Bar                      Bar
# Cluster Start Date           2020-10-01 00:00:00      2020-10-01 00:00:00
# # Cases                                       14                       14
# Latitude_clusters                        36.1639                  36.1639
# Longitude_clusters                      -86.7785                 -86.7785
# Accuracy Score_clusters                        1                        1
# Accuracy Type_clusters       range_interpolation      range_interpolation
# County_clusters                  Davidson County          Davidson County
# Zip_clusters                               37201                    37201
# matches                       207 Printers Alley       207 Printers Alley
# Request #                                 419752                   471299
# Status                                    Closed                   Closed
# Date / Time Opened           2020-07-17 20:55:36      2020-09-26 18:30:59
# Date / Time Closed           2020-07-20 16:56:40      2020-09-28 16:30:16
# Contact Type                                 NaN                      NaN
# State Issue                                False                    False
# Closed When Created                        False                    False
# Address                       207 Printers Alley       207 Printers Alley
# City_violations                        NASHVILLE                NASHVILLE
# Council District                              19                       19
# ZIP                                        37201                    37201
# Mapped Location            (36.16437, -86.77852)  (36.164369, -86.778515)
# Address_geo                   207 Printers Alley       207 Printers Alley
# City_geo                               NASHVILLE                NASHVILLE
# ZIP_geo                                    37201                    37201
# state                                         TN                       TN
# Latitude_violations                      36.1639                  36.1639
# Longitude_violations                    -86.7785                 -86.7785
# Accuracy Score_violations                      1                        1
# Accuracy Type_violations     range_interpolation      range_interpolation
# Number                                       207                      207
# Street_violations                   Printers Aly             Printers Aly
# City.1                                 Nashville                Nashville
# State_violations                              TN                       TN
# County_violations                Davidson County          Davidson County
# Zip_violations                             37201                    37201
#
#                                                159                      160  \
# Unnamed: 0                                     159                      160
# Cluster Name                          Miss Kelli's             Miss Kelli's
# Street_clusters                 207 Printers Alley       207 Printers Alley
# City_clusters                            Nashville                Nashville
# State_clusters                                  TN                       TN
# Facility Type                                  Bar                      Bar
# Cluster Start Date             2020-10-01 00:00:00      2020-10-01 00:00:00
# # Cases                                         14                       14
# Latitude_clusters                          36.1639                  36.1639
# Longitude_clusters                        -86.7785                 -86.7785
# Accuracy Score_clusters                          1                        1
# Accuracy Type_clusters         range_interpolation      range_interpolation
# County_clusters                    Davidson County          Davidson County
# Zip_clusters                                 37201                    37201
# matches                         207 Printers Alley       207 Printers Alley
# Request #                                   482950                   487902
# Status                                      Closed                   Closed
# Date / Time Opened             2020-10-18 04:24:54      2020-10-25 04:22:34
# Date / Time Closed             2020-10-19 16:03:15      2020-10-26 14:37:35
# Contact Type                                   NaN                      NaN
# State Issue                                  False                    False
# Closed When Created                          False                    False
# Address                         207 Printers Alley       207 Printers Alley
# City_violations                          NASHVILLE                NASHVILLE
# Council District                                19                       19
# ZIP                                          37201                    37201
# Mapped Location            (36.164369, -86.778515)  (36.164369, -86.778515)
# Address_geo                     207 Printers Alley       207 Printers Alley
# City_geo                                 NASHVILLE                NASHVILLE
# ZIP_geo                                      37201                    37201
# state                                           TN                       TN
# Latitude_violations                        36.1639                  36.1639
# Longitude_violations                      -86.7785                 -86.7785
# Accuracy Score_violations                        1                        1
# Accuracy Type_violations       range_interpolation      range_interpolation
# Number                                         207                      207
# Street_violations                     Printers Aly             Printers Aly
# City.1                                   Nashville                Nashville
# State_violations                                TN                       TN
# County_violations                  Davidson County          Davidson County
# Zip_violations                               37201                    37201
#
#                                                                162  \
# Unnamed: 0                                                     162
# Cluster Name                                 Link Systems Electric
# Street_clusters                                     444 McNally Dr
# City_clusters                                            Nashville
# State_clusters                                                  TN
# Facility Type                                       Other Business
# Cluster Start Date                             2020-10-16 00:00:00
# # Cases                                                         12
# Latitude_clusters                                          36.0926
# Longitude_clusters                                        -86.7403
# Accuracy Score_clusters                                        0.9
# Accuracy Type_clusters                         range_interpolation
# County_clusters                                    Davidson County
# Zip_clusters                                                 37211
# matches                                             444 McNally Dr
# Request #                                                   479073
# Status                                                      Closed
# Date / Time Opened                             2020-10-11 00:52:25
# Date / Time Closed                             2020-10-12 14:12:04
# Contact Type                                                   NaN
# State Issue                                                  False
# Closed When Created                                          False
# Address                                             444 McNally Dr
# City_violations                                          NASHVILLE
# Council District                                                26
# ZIP                                                          37211
# Mapped Location            (36.09275076157706, -86.74174550000001)
# Address_geo                                         444 McNally Dr
# City_geo                                                 NASHVILLE
# ZIP_geo                                                      37211
# state                                                           TN
# Latitude_violations                                        36.0926
# Longitude_violations                                      -86.7403
# Accuracy Score_violations                                      0.9
# Accuracy Type_violations                       range_interpolation
# Number                                                         444
# Street_violations                                      Mc Nally Dr
# City.1                                                   Nashville
# State_violations                                                TN
# County_violations                                  Davidson County
# Zip_violations                                               37211
#
#                                                 163                       164  \
# Unnamed: 0                                      163                       164
# Cluster Name                  Link Systems Electric     Link Systems Electric
# Street_clusters                      444 McNally Dr            444 McNally Dr
# City_clusters                             Nashville                 Nashville
# State_clusters                                   TN                        TN
# Facility Type                        Other Business            Other Business
# Cluster Start Date              2020-10-16 00:00:00       2020-10-16 00:00:00
# # Cases                                          12                        12
# Latitude_clusters                           36.0926                   36.0926
# Longitude_clusters                         -86.7403                  -86.7403
# Accuracy Score_clusters                         0.9                       0.9
# Accuracy Type_clusters          range_interpolation       range_interpolation
# County_clusters                     Davidson County           Davidson County
# Zip_clusters                                  37211                     37211
# matches                              444 McNally Dr            444 McNally Dr
# Request #                                    483497                    478085
# Status                                       Closed                    Closed
# Date / Time Opened              2020-10-19 15:58:47       2020-10-08 19:38:26
# Date / Time Closed              2020-10-20 13:57:26       2020-10-09 13:29:02
# Contact Type                                    NaN                       NaN
# State Issue                                   False                     False
# Closed When Created                           False                     False
# Address                              444 McNally Dr            444 McNally Dr
# City_violations                           NASHVILLE                 NASHVILLE
# Council District                                 26                        26
# ZIP                                           37211                     37211
# Mapped Location            (36.0930056, -86.741716)  (36.0930056, -86.741716)
# Address_geo                          444 McNally Dr            444 McNally Dr
# City_geo                                  NASHVILLE                 NASHVILLE
# ZIP_geo                                       37211                     37211
# state                                            TN                        TN
# Latitude_violations                         36.0926                   36.0926
# Longitude_violations                       -86.7403                  -86.7403
# Accuracy Score_violations                       0.9                       0.9
# Accuracy Type_violations        range_interpolation       range_interpolation
# Number                                          444                       444
# Street_violations                       Mc Nally Dr               Mc Nally Dr
# City.1                                    Nashville                 Nashville
# State_violations                                 TN                        TN
# County_violations                   Davidson County           Davidson County
# Zip_violations                                37211                     37211
#
#                                                 165
# Unnamed: 0                                      165
# Cluster Name                  Link Systems Electric
# Street_clusters                      444 McNally Dr
# City_clusters                             Nashville
# State_clusters                                   TN
# Facility Type                        Other Business
# Cluster Start Date              2020-10-16 00:00:00
# # Cases                                          12
# Latitude_clusters                           36.0926
# Longitude_clusters                         -86.7403
# Accuracy Score_clusters                         0.9
# Accuracy Type_clusters          range_interpolation
# County_clusters                     Davidson County
# Zip_clusters                                  37211
# matches                              444 McNally Dr
# Request #                                    481365
# Status                                       Closed
# Date / Time Opened              2020-10-15 13:47:48
# Date / Time Closed              2020-10-16 13:27:18
# Contact Type                                    NaN
# State Issue                                   False
# Closed When Created                           False
# Address                              444 McNally Dr
# City_violations                           NASHVILLE
# Council District                                 26
# ZIP                                           37211
# Mapped Location            (36.0930056, -86.741716)
# Address_geo                          444 McNally Dr
# City_geo                                  NASHVILLE
# ZIP_geo                                       37211
# state                                            TN
# Latitude_violations                         36.0926
# Longitude_violations                       -86.7403
# Accuracy Score_violations                       0.9
# Accuracy Type_violations        range_interpolation
# Number                                          444
# Street_violations                       Mc Nally Dr
# City.1                                    Nashville
# State_violations                                 TN
# County_violations                   Davidson County
# Zip_violations                                37211
#
# [41 rows x 145 columns]

# %%
violations_strip = alt.Chart(fuzzy_strip).mark_tick(opacity=.5, thickness=1.5).encode(
    x = alt.X('Date / Time Opened', axis = alt.Axis(
        title = 'Date of Violation Report (Blue) and Cluster Start Date (Red)', format = ("%B"), grid=False)),
    y = alt.Y('Cluster Name', axis = alt.Axis(title = 'Cluster Location', grid=True)),
    size=alt.value(38)
).properties(
    width=700,
    height=400,
    title='COVID-19 Clusters and Violation Reports over Time'
)

cluster_strip = alt.Chart(fuzzy_strip).mark_tick(thickness=2.5).encode(
    x="Cluster Start Date",
    y="Cluster Name",
    color=alt.value('red'),
    size=alt.value(38)
)

violations_strip + cluster_strip
# Out:
# alt.LayerChart(...)

# %%
violations_strip = alt.Chart(fuzzy_strip).mark_tick(opacity=.5, thickness=1.5).encode(
    x = alt.X('Date / Time Opened', axis = alt.Axis(
        title = 'Date of Violation Report and Cluster Start Date (Red)', format = ("%B"), grid=False)), color='Facility Type',
    y = alt.Y('Cluster Name', axis = alt.Axis(title = 'Cluster Location', grid=True)),
    size=alt.value(38)
).properties(
    width=700,
    height=400,
    title='COVID-19 Clusters and Violation Reports over Time'
)

cluster_strip = alt.Chart(fuzzy_strip).mark_tick(thickness=2.5).encode(
    x="Cluster Start Date",
    y="Cluster Name",
    color=alt.value('red'),
    size=alt.value(38)
)

violations_strip + cluster_strip
# Out:
# alt.LayerChart(...)
